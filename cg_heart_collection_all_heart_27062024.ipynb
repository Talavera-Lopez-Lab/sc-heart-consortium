# %% [markdown]
# # Notebook to download heart data from 'CellxGene'
#
# **Developed by** :Srivalli Kolla
#
# **Created on** : 27 June, 2024
#
# **Last modified** : 27 June, 2024
#
# **Würzburg Institute for Systems Immunology & Julius-Maximilian-Universität Würzburg**

# %% [markdown]
# # Importing packages

# %%
import cellxgene_census
import numpy as np
import pandas as pd
import scanpy as sc
import os

# %% [markdown]
# # Data import and overview

# %% [markdown]
# ## Query to check the census about dataset required

# %%
census = cellxgene_census.open_soma()
summary_table = census["census_info"]["summary_cell_counts"].read().concat().to_pandas()

summary_table.query("organism == 'Homo sapiens' & label =='heart'")
# Out:
# The "stable" release is currently 2023-12-15. Specify 'census_version="2023-12-15"' in future calls to open_soma() to ensure data consistency.
#       soma_joinid      organism        category ontology_term_id  \
# 783           783  Homo sapiens          tissue   UBERON:0000948
# 1000         1000  Homo sapiens  tissue_general   UBERON:0000948
#
#       unique_cell_count  total_cell_count  label
# 783              112532            137624  heart
# 1000            1776351           3629952  heart

# %% [markdown]
# ## Loading data from census

# %%
heart_obs = (
    census["census_data"]["homo_sapiens"]
    .obs.read(value_filter="tissue_general == 'heart' or tissue == 'heart' and is_primary_data == True")
    .concat()
    .to_pandas()
)
heart_obs
# Out:
#          soma_joinid                            dataset_id          assay  \
# 0            2517346  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 1            2517347  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 2            2517348  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 3            2517349  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 4            2517350  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# ...              ...                                   ...            ...
# 3629947     62887152  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629948     62887153  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629949     62887154  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629950     62887155  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629951     62887156  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
#
#         assay_ontology_term_id         cell_type cell_type_ontology_term_id  \
# 0                  EFO:0009899  endothelial cell                 CL:0000115
# 1                  EFO:0009899        mural cell                 CL:0008034
# 2                  EFO:0009899  endothelial cell                 CL:0000115
# 3                  EFO:0009899        mural cell                 CL:0008034
# 4                  EFO:0009899  endothelial cell                 CL:0000115
# ...                        ...               ...                        ...
# 3629947            EFO:0030002  endothelial cell                 CL:0000115
# 3629948            EFO:0030002  endothelial cell                 CL:0000115
# 3629949            EFO:0030002  endothelial cell                 CL:0000115
# 3629950            EFO:0030002  endothelial cell                 CL:0000115
# 3629951            EFO:0030002  endothelial cell                 CL:0000115
#
#                                 development_stage  \
# 0                        sixth decade human stage
# 1                        sixth decade human stage
# 2                        sixth decade human stage
# 3                        sixth decade human stage
# 4                        sixth decade human stage
# ...                                           ...
# 3629947  11th week post-fertilization human stage
# 3629948  11th week post-fertilization human stage
# 3629949  11th week post-fertilization human stage
# 3629950  11th week post-fertilization human stage
# 3629951  11th week post-fertilization human stage
#
#         development_stage_ontology_term_id disease disease_ontology_term_id  \
# 0                           HsapDv:0000240  normal             PATO:0000461
# 1                           HsapDv:0000240  normal             PATO:0000461
# 2                           HsapDv:0000240  normal             PATO:0000461
# 3                           HsapDv:0000240  normal             PATO:0000461
# 4                           HsapDv:0000240  normal             PATO:0000461
# ...                                    ...     ...                      ...
# 3629947                     HsapDv:0000048  normal             PATO:0000461
# 3629948                     HsapDv:0000048  normal             PATO:0000461
# 3629949                     HsapDv:0000048  normal             PATO:0000461
# 3629950                     HsapDv:0000048  normal             PATO:0000461
# 3629951                     HsapDv:0000048  normal             PATO:0000461
#
#          ... suspension_type         tissue tissue_ontology_term_id  \
# 0        ...            cell  apex of heart          UBERON:0002098
# 1        ...            cell  apex of heart          UBERON:0002098
# 2        ...            cell  apex of heart          UBERON:0002098
# 3        ...            cell  apex of heart          UBERON:0002098
# 4        ...            cell  apex of heart          UBERON:0002098
# ...      ...             ...            ...                     ...
# 3629947  ...            cell          heart          UBERON:0000948
# 3629948  ...            cell          heart          UBERON:0000948
# 3629949  ...            cell          heart          UBERON:0000948
# 3629950  ...            cell          heart          UBERON:0000948
# 3629951  ...            cell          heart          UBERON:0000948
#
#         tissue_general tissue_general_ontology_term_id raw_sum   nnz  \
# 0                heart                  UBERON:0000948  7123.0  2467
# 1                heart                  UBERON:0000948  6091.0  2054
# 2                heart                  UBERON:0000948  6248.0  2426
# 3                heart                  UBERON:0000948  5862.0  1819
# 4                heart                  UBERON:0000948  4920.0  2330
# ...                ...                             ...     ...   ...
# 3629947          heart                  UBERON:0000948   560.0   402
# 3629948          heart                  UBERON:0000948   758.0   515
# 3629949          heart                  UBERON:0000948   568.0   414
# 3629950          heart                  UBERON:0000948   418.0   300
# 3629951          heart                  UBERON:0000948   506.0   401
#
#         raw_mean_nnz raw_variance_nnz n_measured_vars
# 0           2.887313        62.875374           31071
# 1           2.965433       282.782536           31071
# 2           2.575433        44.868741           31071
# 3           3.222650        94.875042           31071
# 4           2.111588        23.759119           31071
# ...              ...              ...             ...
# 3629947     1.393035         2.174315           26454
# 3629948     1.471845         2.724400           26454
# 3629949     1.371981         1.648220           26454
# 3629950     1.393333         2.312999           26454
# 3629951     1.261845         0.368766           26454
#
# [3629952 rows x 26 columns]

# %% [markdown]
# ## Data overview

# %%
heart_obs['assay'].unique()
# Out:
# array(["10x 3' v2", "10x 3' v3", 'Smart-seq2', 'sci-RNA-seq',
#        'microwell-seq'], dtype=object)

# %%
heart_obs['disease'].unique()
# Out:
# array(['normal', 'myocardial infarction', 'dilated cardiomyopathy',
#        'arrhythmogenic right ventricular cardiomyopathy',
#        'non-compaction cardiomyopathy'], dtype=object)

# %%
heart_obs[["suspension_type"]].value_counts()
# Out:
# suspension_type
# nucleus            3151688
# cell                478264
# Name: count, dtype: int64

# %%
heart_obs[["cell_type"]].value_counts().head(20)
# Out:
# cell_type
# cardiac muscle cell                    746616
# mural cell                             430361
# regular ventricular cardiac myocyte    393506
# endothelial cell                       365728
# fibroblast of cardiac tissue           337813
# fibroblast                             214619
# pericyte                               173035
# myeloid cell                           150168
# capillary endothelial cell             120582
# native cell                            102501
# regular atrial cardiac myocyte          73489
# cardiac muscle myoblast                 66335
# lymphocyte                              50971
# cardiac endothelial cell                44999
# smooth muscle cell                      43926
# endothelial cell of artery              42405
# macrophage                              34963
# immature innate lymphoid cell           28651
# stromal cell                            19564
# vein endothelial cell                   17868
# Name: count, dtype: int64

# %%
heart_obs[["tissue"]].value_counts()
# Out:
# tissue
# heart left ventricle               1349023
# heart right ventricle               698008
# interventricular septum             645583
# apex of heart                       353385
# left cardiac atrium                 219093
# heart                               137624
# right cardiac atrium                127638
# anterior wall of left ventricle      36574
# cardiac atrium                       24837
# basal zone of heart                  18775
# coronary artery                       9734
# cardiac ventricle                     9678
# Name: count, dtype: int64

# %% [markdown]
# # Adding dataset information

# %% [markdown]
# ## Collection of dataset information

# %%
census_datasets = (
    census["census_info"]["datasets"]
    .read(column_names=["collection_name", "dataset_title", "dataset_id", "soma_joinid"])
    .concat()
    .to_pandas()
)
census_datasets = census_datasets.set_index("dataset_id")
census_datasets
# Out:
#                                                                         collection_name  \
# dataset_id
# 2bdd3a2c-2ff4-4314-adf3-8a06b797a33a  Comparative transcriptomics reveals human-spec...
# f5b0810c-1664-4a62-ad06-be1d9964aa8b  Transcriptomic cytoarchitecture reveals princi...
# e4ddac12-f48f-4455-8e8d-c2a48a683437  Transcriptomic cytoarchitecture reveals princi...
# e2808a6e-e2ea-41b9-b38c-4a08f1677f02  Transcriptomic cytoarchitecture reveals princi...
# d01c9dff-abd1-4825-bf30-2eb2ba74597e  Transcriptomic cytoarchitecture reveals princi...
# ...                                                                                 ...
# f9ad5649-f372-43e1-a3a8-423383e5a8a2  Molecular characterization of selectively vuln...
# 456e8b9b-f872-488b-871d-94534090a865  Single-cell atlas of peripheral immune respons...
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  Construction of a human cell landscape at sing...
# e04daea4-4412-45b5-989e-76a9be070a89  A molecular cell atlas of the human lung from ...
# 8c42cfd0-0b0a-46d5-910c-fc833d83c45e  A molecular cell atlas of the human lung from ...
#
#                                                                           dataset_title  \
# dataset_id
# 2bdd3a2c-2ff4-4314-adf3-8a06b797a33a                            Human: Great apes study
# f5b0810c-1664-4a62-ad06-be1d9964aa8b                    Dissection: Angular gyrus (AnG)
# e4ddac12-f48f-4455-8e8d-c2a48a683437             Supercluster: CGE-derived interneurons
# e2808a6e-e2ea-41b9-b38c-4a08f1677f02            Dissection: Primary auditory cortex(A1)
# d01c9dff-abd1-4825-bf30-2eb2ba74597e  Supercluster: Deep layer (non-IT) excitatory n...
# ...                                                                                 ...
# f9ad5649-f372-43e1-a3a8-423383e5a8a2  Molecular characterization of selectively vuln...
# 456e8b9b-f872-488b-871d-94534090a865  Single-cell atlas of peripheral immune respons...
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  Construction of a human cell landscape at sing...
# e04daea4-4412-45b5-989e-76a9be070a89      Krasnow Lab Human Lung Cell Atlas, Smart-seq2
# 8c42cfd0-0b0a-46d5-910c-fc833d83c45e             Krasnow Lab Human Lung Cell Atlas, 10X
#
#                                       soma_joinid
# dataset_id
# 2bdd3a2c-2ff4-4314-adf3-8a06b797a33a            0
# f5b0810c-1664-4a62-ad06-be1d9964aa8b            1
# e4ddac12-f48f-4455-8e8d-c2a48a683437            2
# e2808a6e-e2ea-41b9-b38c-4a08f1677f02            3
# d01c9dff-abd1-4825-bf30-2eb2ba74597e            4
# ...                                           ...
# f9ad5649-f372-43e1-a3a8-423383e5a8a2          646
# 456e8b9b-f872-488b-871d-94534090a865          647
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf          648
# e04daea4-4412-45b5-989e-76a9be070a89          649
# 8c42cfd0-0b0a-46d5-910c-fc833d83c45e          650
#
# [651 rows x 3 columns]

# %% [markdown]
# ## Addition of dataset information to our heart data

# %%
dataset_cell_counts = pd.DataFrame(heart_obs[["dataset_id"]].value_counts())
dataset_cell_counts = dataset_cell_counts.rename(columns={0: "cell_counts"})
dataset_cell_counts = dataset_cell_counts.merge(census_datasets, on="dataset_id")

dataset_cell_counts
# Out:
#                                        count  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  881081
# d567b692-c374-4628-a508-8008f6778f22  493236
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e  486134
# f7995301-7551-4e1d-8396-ffe3c9497ace  311418
# 572f3f3e-d3e4-4d13-8e2b-88215e508481  195395
# 1c739a3e-c3f5-49d5-98e0-73975e751201  191795
# 1252c5fb-945f-42d6-b1a8-8a3bd864384b  170281
# ed2b673b-0279-454a-998c-3eec361edf54  142816
# 78fd69d2-75e4-4207-819a-563139f273c6  125289
# 1062c0f2-2a44-4cf9-a7c8-b5ed58b4728d  115548
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353  101749
# 5500c673-1610-40a0-86d9-64d987ae50e6   60668
# 9d584fcb-a28a-4b91-a886-ceb66a88ef81   59341
# 9434b020-de42-43eb-bcc4-542b2be69015   59217
# ed852810-a003-4386-9846-1638362cee39   40868
# 4ed927e9-c099-49af-b8ce-a2652d069333   36574
# fa27492b-82ff-4ab7-ac61-0e2b184eee67   25092
# 84f1a631-910b-4fbb-9f76-d915a07316d2   23483
# f15e263b-6544-46cb-a46e-e33ab7ce8347   19722
# 0fdb6122-4600-40f0-a703-2da47cc7080d   16878
# 53d208b0-2cfd-4366-9866-c3c6114081bc   16372
# e6a11140-2545-46bc-929e-da243eed2cae   11505
# a68b64d8-aee3-4947-81b7-36b8fe5a44d2   11382
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf   10783
# 83b5e943-a1d5-4164-b3f2-f7a37f01b524    7999
# 1009f384-b12d-448e-ba9f-1b7d2ecfbb4e    3961
# f75f2ff4-2884-4c2d-b375-70de37a34507    3799
# 5a11f879-d1ef-458a-910c-9b0bdfca5ebf    2834
# bdf69f8d-5a96-4d6f-a9f5-9ee0e33597b7    2576
# 97a17473-e2b1-4f31-a544-44a60773e2dd    1089
# c5d88abe-f23a-45fa-a534-788985e93dad    1067
#
#                                                                         collection_name  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  Pathogenic variants damage cell composition an...
# d567b692-c374-4628-a508-8008f6778f22  Spatially resolved multiomics of human cardiac...
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e                     Cells of the adult human heart
# f7995301-7551-4e1d-8396-ffe3c9497ace  Pathogenic variants damage cell composition an...
# 572f3f3e-d3e4-4d13-8e2b-88215e508481                     Cells of the adult human heart
# 1c739a3e-c3f5-49d5-98e0-73975e751201  Spatial multi-omic map of human myocardial inf...
# 1252c5fb-945f-42d6-b1a8-8a3bd864384b  Pathogenic variants damage cell composition an...
# ed2b673b-0279-454a-998c-3eec361edf54  Pathogenic variants damage cell composition an...
# 78fd69d2-75e4-4207-819a-563139f273c6                     Cells of the adult human heart
# 1062c0f2-2a44-4cf9-a7c8-b5ed58b4728d  Pathogenic variants damage cell composition an...
# f7c1c579-2dc0-47e2-ba19-8165c5a0e
# 1009f384-b12d-448e-ba9f-1b7d2ecfbb4e          557
# f75f2ff4-2884-4c2d-b375-70de37a34507          562
# 5a11f879-d1ef-458a-910c-9b0bdfca5ebf          536
# bdf69f8d-5a96-4d6f-a9f5-9ee0e33597b7          394
# 97a17473-e2b1-4f31-a544-44a60773e2dd          537
# c5d88abe-f23a-45fa-a534-788985e93dad          535

# %% [markdown]
# # Adding gene information

# %% [markdown]
# ## Collection of gene information for all Human

# %%
all_var = census["census_data"]["homo_sapiens"].ms["RNA"].var.read().concat().to_pandas()
all_var
# Out:
#        soma_joinid       feature_id   feature_name  feature_length      nnz  \
# 0                0  ENSG00000233576        HTR3C2P            1057    69370
# 1                1  ENSG00000121410           A1BG            3999  5640476
# 2                2  ENSG00000268895       A1BG-AS1            3374  3071864
# 3                3  ENSG00000148584           A1CF            9603   734347
# 4                4  ENSG00000175899            A2M            6318  7894261
# ...            ...              ...            ...             ...      ...
# 60659        60659  ENSG00000288719  RP4-669P10.21            4252     2826
# 60660        60660  ENSG00000288720  RP11-852E15.3            7007       99
# 60661        60661  ENSG00000288721   RP5-973N23.5            7765        0
# 60662        60662  ENSG00000288723  RP11-553N16.6            1015       18
# 60663        60663  ENSG00000288724   RP13-546I2.2             625       36
#
#        n_measured_obs
# 0            19581263
# 1            62641311
# 2            61946057
# 3            58195911
# 4            62704378
# ...               ...
# 60659         1248980
# 60660         1248980
# 60661               0
# 60662         1248980
# 60663         1248980
#
# [60664 rows x 6 columns]

# %% [markdown]
# ## Collection of gene information specific to our dataset based on 'soma_joinid'

# %%
presence_matrix = cellxgene_census.get_presence_matrix(census, "Homo sapiens", "RNA")
presence_matrix = presence_matrix[dataset_cell_counts.soma_joinid, :]
presence_matrix.sum(axis=1).A1genes_measured = presence_matrix.sum(axis=1).A1

# %%
genes_measured = presence_matrix.sum(axis=1).A1
dataset_cell_counts["genes_measured"] = genes_measured
dataset_cell_counts
# Out:
#                                        count  \
# dataset_id
# 65badd7a-9262-4fd1-9ce2-eb5dc0ca8039  881081
# d567b692-c374-4628-a508-8008f6778f22  493236
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e  486134
# f7995301-7551-4e1d-8396-ffe3c9497ace  311418
# 572f3f3e-d3e4-4d13-8e2b-88215e508481  195395
# 1c739a3e-c3f5-49d5-98e0-73975e751201  191795
# 1252c5fb-945f-42d6-b1a8-8a3bd864384b  170281
# ed2b673b-0279-454a-998c-3eec361edf54  142816
# 78fd69d2-75e4-4207-819a-563139f273c6  125289
# 1062c0f2-2a44-4cf9-a7c8-b5ed58b4728d  115548
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353  101749
# 5500c673-1610-40a0-86d9-64d987ae50e6   60668
# 9d584fcb-a28a-4b91-a886-ceb66a88ef81   59341
# 9434b020-de42-43eb-bcc4-542b2be69015   59217
# ed852810-a003-4386-9846-1638362cee39   40868
# 4ed927e9-c099-49af-b8ce-a2652d069333   36574
# fa27492b-82ff-4ab7-ac61-0e2b184eee67   25092
# 84f1a631-910b-4fbb-9f76-d915a07316d2   23483
# f15e263b-6544-46cb-a46e-e33ab7ce8347   19722
# 0fdb6122-4600-40f0-a703-2da47cc7080d   16878
# d567b692-c374-4628-a508-8008f6778f22           15           31071
# d4e69e01-3ba2-4d6b-a15d-e7048f78f22e          563           31303
# f7995301-7551-4e1d-8396-ffe3c9497ace          392           30149
# 572f3f3e-d3e4-4d13-8e2b-88215e508481          556           30156
# 1c739a3e-c3f5-49d5-98e0-73975e751201          391           29012
# 1252c5fb-945f-42d6-b1a8-8a3bd864384b          398            6445
# ed2b673b-0279-454a-998c-3eec361edf54          393           29329
# 78fd69d2-75e4-4207-819a-563139f273c6          560           28956
# 1062c0f2-2a44-4cf9-a7c8-b5ed58b4728d          399           28681
# f7c1c579-2dc0-47e2-ba19-8165c5a0e353          541           44150
# 5500c673-1610-40a0-86d9-64d987ae50e6          187           27470
# 9d584fcb-a28a-4b91-a886-ceb66a88ef81          559           29127
# 9434b020-de42-43eb-bcc4-542b2be69015          395            3424
# ed852810-a003-4386-9846-1638362cee39          558           28500
# 4ed927e9-c099-49af-b8ce-a2652d069333          426           29620
# fa27492b-82ff-4ab7-ac61-0e2b184eee67          542           41357
# 84f1a631-910b-4fbb-9f76-d915a07316d2          561           27699
# f15e263b-6544-46cb-a46e-e33ab7ce8347          390           20726
# 0fdb6122-4600-40f0-a703-2da47cc7080d          400           26249
# 53d208b0-2cfd-4366-9866-c3c6114081bc          533           57042
# e6a11140-2545-46bc-929e-da243eed2cae           65           41162
# a68b64d8-aee3-4947-81b7-36b8fe5a44d2          534           55995
# 2adb1f8a-a6b1-4909-8ee8-484814e2d4bf          648           26454
# 83b5e943-a1d5-4164-b3f2-f7a37f01b524          396            3886
# 1009f384-b12d-448e-ba9f-1b7d2ecfbb4e          557           25317
# f75f2ff4-2884-4c2d-b375-70de37a34507          562           26455
# 5a11f879-d1ef-458a-910c-9b0bdfca5ebf          536           51591
# bdf69f8d-5a96-4d6f-a9f5-9ee0e33597b7          394           25362
# 97a17473-e2b1-4f31-a544-44a60773e2dd          537           55934
# c5d88abe-f23a-45fa-a534-788985e93dad          535           56465

# %% [markdown]
# # Adding gene metadata

# %% [markdown]
# ## Genes info from all datasets

# %%
var_somaid = np.nonzero(presence_matrix.sum(axis=0).A1 == presence_matrix.shape[0])[0].tolist()

# %% [markdown]
# ## Filtering genes matching our soma_joinid

# %%
heart_var = all_var.query(f"soma_joinid in {var_somaid}")
heart_var
# Out:
#        soma_joinid       feature_id  feature_name  feature_length       nnz  \
# 37              37  ENSG00000165029         ABCA1           11343   9001659
# 38              38  ENSG00000154263        ABCA10            8405  11705270
# 40              40  ENSG00000144452        ABCA12            9614    976134
# 51              51  ENSG00000231749     ABCA9-AS1            2990   2783190
# 55              55  ENSG00000005471         ABCB4            7728   1112933
# ...            ...              ...           ...             ...       ...
# 43728        43728  ENSG00000270792  RP11-103J8.1            2623   2109618
# 44236        44236  ENSG00000269124   AC007193.10             472   1045514
# 44515        44515  ENSG00000229999     SGSM3-AS1             893   3074526
# 44616        44616  ENSG00000224905    AP001347.6            1797   9868751
# 44669        44669  ENSG00000232855    AF131217.1            9437   6615371
#
#        n_measured_obs
# 37           62902272
# 38           62845653
# 40           60881315
# 51           55808577
# 55           62817959
# ...               ...
# 43728        55288866
# 44236        49989821
# 44515        55144540
# 44616        56221168
# 44669        56714777
#
# [1035 rows x 6 columns]

# %% [markdown]
# # Fetching all single-cell human heart data from the Census

# %%
heart_sample_ids = heart_obs["soma_joinid"].to_numpy()
heart_gene_ids = heart_var["soma_joinid"].to_numpy()
heart_adata = cellxgene_census.get_anndata(
    census,
    organism="Homo sapiens",
    obs_coords=heart_sample_ids,
    var_coords=heart_gene_ids,
)

heart_adata
# Out:
# AnnData object with n_obs × n_vars = 3629952 × 1035
#     obs: 'soma_joinid', 'dataset_id', 'assay', 'assay_ontology_term_id', 'cell_type', 'cell_type_ontology_term_id', 'development_stage', 'development_stage_ontology_term_id', 'disease', 'disease_ontology_term_id', 'donor_id', 'is_primary_data', 'self_reported_ethnicity', 'self_reported_ethnicity_ontology_term_id', 'sex', 'sex_ontology_term_id', 'suspension_type', 'tissue', 'tissue_ontology_term_id', 'tissue_general', 'tissue_general_ontology_term_id', 'raw_sum', 'nnz', 'raw_mean_nnz', 'raw_variance_nnz', 'n_measured_vars'
#     var: 'soma_joinid', 'feature_id', 'feature_name', 'feature_length', 'nnz', 'n_measured_obs'

# %%
heart_adata.obs
# Out:
#          soma_joinid                            dataset_id          assay  \
# 0            2517346  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 1            2517347  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 2            2517348  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 3            2517349  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# 4            2517350  d567b692-c374-4628-a508-8008f6778f22      10x 3' v2
# ...              ...                                   ...            ...
# 3629947     62887152  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629948     62887153  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629949     62887154  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629950     62887155  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
# 3629951     62887156  2adb1f8a-a6b1-4909-8ee8-484814e2d4bf  microwell-seq
#
#         assay_ontology_term_id         cell_type cell_type_ontology_term_id  \
# 0                  EFO:0009899  endothelial cell                 CL:0000115
# 1                  EFO:0009899        mural cell                 CL:0008034
# 2                  EFO:0009899  endothelial cell                 CL:0000115
# 3                  EFO:0009899        mural cell                 CL:0008034
# 4                  EFO:0009899  endothelial cell                 CL:0000115
# ...                        ...               ...                        ...
# 3629947            EFO:0030002  endothelial cell                 CL:0000115
# 3629948            EFO:0030002  endothelial cell                 CL:0000115
# 3629949            EFO:0030002  endothelial cell                 CL:0000115
# 3629950            EFO:0030002  endothelial cell                 CL:0000115
# 3629951            EFO:0030002  endothelial cell                 CL:0000115
#
#                                 development_stage  \
# 0                        sixth decade human stage
# 1                        sixth decade human stage
# 2                        sixth decade human stage
# 3                        sixth decade human stage
# 4                        sixth decade human stage
# ...                                           ...
# 3629947  11th week post-fertilization human stage
# 3629948  11th week post-fertilization human stage
# 3629949  11th week post-fertilization human stage
# 3629950  11th week post-fertilization human stage
# 3629951  11th week post-fertilization human stage
#
#         development_stage_ontology_term_id disease disease_ontology_term_id  \
# 0                           HsapDv:0000240  normal             PATO:0000461
# 1                           HsapDv:0000240  normal             PATO:0000461
# 2                           HsapDv:0000240  normal             PATO:0000461
# 3                           HsapDv:0000240  normal             PATO:0000461
# 4                           HsapDv:0000240  normal             PATO:0000461
# ...                                    ...     ...                      ...
# 3629947                     HsapDv:0000048  normal             PATO:0000461
# 3629948                     HsapDv:0000048  normal             PATO:0000461
# 3629949                     HsapDv:0000048  normal             PATO:0000461
# 3629950                     HsapDv:0000048  normal             PATO:0000461
# 3629951                     HsapDv:0000048  normal             PATO:0000461
#
#          ... suspension_type         tissue tissue_ontology_term_id  \
# 0        ...            cell  apex of heart          UBERON:0002098
# 1        ...            cell  apex of heart          UBERON:0002098
# 2        ...            cell  apex of heart          UBERON:0002098
# 3        ...            cell  apex of heart          UBERON:0002098
# 4        ...            cell  apex of heart          UBERON:0002098
# ...      ...             ...            ...                     ...
# 3629947  ...            cell          heart          UBERON:0000948
# 3629948  ...            cell          heart          UBERON:0000948
# 3629949  ...            cell          heart          UBERON:0000948
# 3629950  ...            cell          heart          UBERON:0000948
# 3629951  ...            cell          heart          UBERON:0000948
#
#         tissue_general tissue_general_ontology_term_id raw_sum   nnz  \
# 0                heart                  UBERON:0000948  7123.0  2467
# 1                heart                  UBERON:0000948  6091.0  2054
# 2                heart                  UBERON:0000948  6248.0  2426
# 3                heart                  UBERON:0000948  5862.0  1819
# 4                heart                  UBERON:0000948  4920.0  2330
# ...                ...                             ...     ...   ...
# 3629947          heart                  UBERON:0000948   560.0   402
# 3629948          heart                  UBERON:0000948   758.0   515
# 3629949          heart                  UBERON:0000948   568.0   414
# 3629950          heart                  UBERON:0000948   418.0   300
# 3629951          heart                  UBERON:0000948   506.0   401
#
#         raw_mean_nnz raw_variance_nnz n_measured_vars
# 0           2.887313        62.875374           31071
# 1           2.965433       282.782536           31071
# 2           2.575433        44.868741           31071
# 3           3.222650        94.875042           31071
# 4           2.111588        23.759119           31071
# ...              ...              ...             ...
# 3629947     1.393035         2.174315           26454
# 3629948     1.471845         2.724400           26454
# 3629949     1.371981         1.648220           26454
# 3629950     1.393333         2.312999           26454
# 3629951     1.261845         0.368766           26454
#
# [3629952 rows x 26 columns]

# %%
heart_adata.obs('suspension_type').unique

# %%
heart_adata.var
# Out:
#       soma_joinid       feature_id  feature_name  feature_length       nnz  \
# 0              37  ENSG00000165029         ABCA1           11343   9001659
# 1              38  ENSG00000154263        ABCA10            8405  11705270
# 2              40  ENSG00000144452        ABCA12            9614    976134
# 3              51  ENSG00000231749     ABCA9-AS1            2990   2783190
# 4              55  ENSG00000005471         ABCB4            7728   1112933
# ...           ...              ...           ...             ...       ...
# 1030        43728  ENSG00000270792  RP11-103J8.1            2623   2109618
# 1031        44236  ENSG00000269124   AC007193.10             472   1045514
# 1032        44515  ENSG00000229999     SGSM3-AS1             893   3074526
# 1033        44616  ENSG00000224905    AP001347.6            1797   9868751
# 1034        44669  ENSG00000232855    AF131217.1            9437   6615371
#
#       n_measured_obs
# 0           62902272
# 1           62845653
# 2           60881315
# 3           55808577
# 4           62817959
# ...              ...
# 1030        55288866
# 1031        49989821
# 1032        55144540
# 1033        56221168
# 1034        56714777
#
# [1035 rows x 6 columns]

# %%
heart_adata.var_names = heart_adata.var["feature_name"]

# %% [markdown]
# ### Closing census

# %%
census.close()
del census

# %% [markdown]
# ## Data saving

# %%
sc.write('data/cg_heart_all_tissue.h5ad',heart_adata)
